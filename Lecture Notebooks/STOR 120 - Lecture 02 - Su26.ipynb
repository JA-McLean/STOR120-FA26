# %% [markdown]
# Run the cell below if you have not completed Lab 01.

# %%
pip install datascience

# %% [markdown]
# Run the cell below. It's for setting up the environment so you can have access to what's needed for this lecture. For now, don't worry about what it means: we'll learn more about that soon.

# %%
from datascience import *

# %% [markdown]
# ## Python ##

# %%
2 + 9

# %%
2 * 9

# %%
2 / 9

# %%
2 + 3 * 9

# %%
(2 + 3) * 9

# %%
# two to the power of four: 2 * 2 * 2 * 2
2 ** 4

# %%
'hello'

# %% [markdown]
# ## Names ##

# %%
a = 4

# %%
a

# %%
b = 9

# %%
b

# %%
a * 3

# %%
total = a + b

# %%
total

# %%
a = 10

# %%
total

# %%
total = a + b

# %%
total

# %%
'total'

# %% [markdown]
# ## Functions and Call Expressions

# %%
abs(-5)

# %%
abs(1 - 3)

# %%
i = 52
j = 47
abs(j - i)

# %%
min(14, 15)

# %%
round(123.456)

# %%
round(123.456, 1)

# %%
round(123.456, ndigits=1)

# %% [markdown]
# ## Tables

# %%
songs = Table.read_table('songs.csv')
songs

# %%
songs.show(3)

# %%
songs.show(100)

# %%
songs.select('artist')

# %%
songs.select('artist', 'name')

# %%
songs.select(artist, 'name')

# %%
songs.drop('duration')

# %%
songs

# %%
songs_without_duration = songs.drop('duration')
songs_without_duration

# %%
songs.where('artist', '"Weird Al" Yankovic')

# %%
songs.where('duration', 240)

# %%
songs.sort('duration')

# %%
songs.sort('duration', descending = True)

# %% [markdown]
# ## Another table

# %%
Arrests = Table.read_table('Police_Arrests_Made.csv')
Arrests

# %%
Arrests.where('Primary_Charge', 'OPEN CONTAINER')

# %%
Arrests.where('City', 'CHAPEL HILL')

# %%
Arrests.where('City', 'CHAPEL HILL').sort('Age')

# %%
Arrests.where('City', 'CHAPEL HILL').sort('Age', descending=True)
